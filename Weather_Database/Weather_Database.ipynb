# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# Import the requests library. (6.2)
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7aaedeac7434dbeebbf811a6cffe63ca

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(0.5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(0.5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")   

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | port alfred
# Processing Record 2 of Set 16 | ushuaia
# Processing Record 3 of Set 16 | weligama
# Processing Record 4 of Set 16 | torbay
# Processing Record 5 of Set 16 | naryan-mar
# Processing Record 6 of Set 16 | rikitea
# Processing Record 7 of Set 16 | vaini
# Processing Record 8 of Set 16 | bardiyah
# Processing Record 9 of Set 16 | provideniya
# Processing Record 10 of Set 16 | emba
# Processing Record 11 of Set 16 | isangel
# Processing Record 12 of Set 16 | padang
# Processing Record 13 of Set 16 | mae sai
# Processing Record 14 of Set 16 | busselton
# Processing Record 15 of Set 16 | nikolskoye
# Processing Record 16 of Set 16 | avera
# Processing Record 17 of Set 16 | nyurba
# Processing Record 18 of Set 16 | airai
# Processing Record 19 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 20 of Set 16 | albany
# Processing Record 21 of Set 16 | mataura
# Processing Record 22 of Set 16 | kulhudhuffushi
# Processing Record 23 of Set 16 | guano
# Processing Record 24 of Set 16 | bereda
# Processing Record 25 of Set 16 | kapaa
# Processing Record 26 of Set 16 | bredasdorp
# Processing Record 27 of Set 16 | bengkulu
# Processing Record 28 of Set 16 | yar-sale
# Processing Record 29 of Set 16 | tasiilaq
# Processing Record 30 of Set 16 | tiksi
# Processing Record 31 of Set 16 | bluff
# Processing Record 32 of Set 16 | shelopugino
# Processing Record 33 of Set 16 | nara
# Processing Record 34 of Set 16 | barrow
# Processing Record 35 of Set 16 | altamont
# Processing Record 36 of Set 16 | muana
# Processing Record 37 of Set 16 | galia
# Processing Record 38 of Set 16 | new norfolk
# Processing Record 39 of Set 16 | anadyr
# Processing Record 40 of Set 16 | pisco
# Processing Record 41 of Set 16 | tuktoyaktuk
# Processing Record 42 of Set 16 | pegnitz
# Processing Record 43 of Set 16 | san cristobal
# Processing Record 44 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 16 | coronado
# Processing Record 46 of Set 16 | puerto ayora
# Processing Record 47 of Set 16 | dikson
# Processing Record 48 of Set 16 | atuona
# Processing Record 49 of Set 16 | okhotsk
# Processing Record 50 of Set 16 | hamilton
# Processing Record 1 of Set 17 | saldanha
# Processing Record 2 of Set 17 | sorland
# Processing Record 3 of Set 17 | naze
# Processing Record 4 of Set 17 | clyde river
# Processing Record 5 of Set 17 | lebu
# Processing Record 6 of Set 17 | morondava
# Processing Record 7 of Set 17 | coolum beach
# Processing Record 8 of Set 17 | mackay
# Processing Record 9 of Set 17 | adre
# Processing Record 10 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 17 | toucheng
# Processing Record 12 of Set 17 | paamiut
# Processing Record 13 of Set 17 | sioux lookout
# Processing Record 14 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 17 | andenes
# Processing Record 16 of Set 17 | jamestown
# Processing Record 17 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 17 | vila franca do campo
# Processing Record 19 of Set 17 | coahuayana
# Processing Record 20 of Set 17 | melfi
# Processing Record 21 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 17 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 17 | ponta do sol
# Processing Record 24 of Set 17 | warrington
# Processing Record 25 of Set 17 | chuy
# Processing Record 26 of Set 17 | bonavista
# Processing Record 27 of Set 17 | ilulissat
# Processing Record 28 of Set 17 | demba
# Processing Record 29 of Set 17 | san patricio
# Processing Record 30 of Set 17 | maarianhamina
# Processing Record 31 of Set 17 | hilo
# Processing Record 32 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 17 | uyuni
# Processing Record 34 of Set 17 | iwanai
# Processing Record 35 of Set 17 | qaanaaq
# Processing Record 36 of Set 17 | altonia
# City not found. Skipping...
# Processing Record 37 of Set 17 | bambous virieux
# Processing Record 38 of Set 17 | portland
# Processing Record 39 of Set 17 | maniitsoq
# Processing Record 40 of Set 17 | kununurra
# Processing Record 41 of Set 17 | ulagan
# Processing Record 42 of Set 17 | bundi
# Processing Record 43 of Set 17 | namibe
# Processing Record 44 of Set 17 | port hardy
# Processing Record 45 of Set 17 | port elizabeth
# Processing Record 46 of Set 17 | severo-kurilsk
# Processing Record 47 of Set 17 | balabac
# Processing Record 48 of Set 17 | mount gambier
# Processing Record 49 of Set 17 | vestbygda
# City not found. Skipping...
# Processing Record 50 of Set 17 | saint george
# Processing Record 1 of Set 18 | shieli
# Processing Record 2 of Set 18 | necochea
# Processing Record 3 of Set 18 | hermanus
# Processing Record 4 of Set 18 | tura
# Processing Record 5 of Set 18 | ust-uda
# Processing Record 6 of Set 18 | braslav
# City not found. Skipping...
# Processing Record 7 of Set 18 | beringovskiy
# Processing Record 8 of Set 18 | talnakh
# Processing Record 9 of Set 18 | dingle
# Processing Record 10 of Set 18 | englewood
# Processing Record 11 of Set 18 | tesistan
# Processing Record 12 of Set 18 | grindavik
# Processing Record 13 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 18 | marsa matruh
# Processing Record 15 of Set 18 | cap malheureux
# Processing Record 16 of Set 18 | butaritari
# Processing Record 17 of Set 18 | saint-philippe
# Processing Record 18 of Set 18 | nanortalik
# Processing Record 19 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 18 | thompson
# Processing Record 21 of Set 18 | sambava
# Processing Record 22 of Set 18 | kodiak
# Processing Record 23 of Set 18 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 18 | pevek
# Processing Record 25 of Set 18 | castro
# Processing Record 26 of Set 18 | sumbe
# Processing Record 27 of Set 18 | khatanga
# Processing Record 28 of Set 18 | cabo san lucas
# Processing Record 29 of Set 18 | homer
# Processing Record 30 of Set 18 | dunedin
# Processing Record 31 of Set 18 | yellowknife
# Processing Record 32 of Set 18 | hasaki
# Processing Record 33 of Set 18 | port maria
# Processing Record 34 of Set 18 | esmeraldas
# Processing Record 35 of Set 18 | raton
# Processing Record 36 of Set 18 | aklavik
# Processing Record 37 of Set 18 | punta arenas
# Processing Record 38 of Set 18 | rio grande
# Processing Record 39 of Set 18 | bethel
# Processing Record 40 of Set 18 | broome
# Processing Record 41 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 18 | yilan
# Processing Record 43 of Set 18 | richards bay
# Processing Record 44 of Set 18 | kamiiso
# Processing Record 45 of Set 18 | carnarvon
# Processing Record 46 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 18 | springbok
# Processing Record 48 of Set 18 | sao felix do xingu
# Processing Record 49 of Set 18 | kruisfontein
# Processing Record 50 of Set 18 | souillac
# Processing Record 1 of Set 19 | rawson
# Processing Record 2 of Set 19 | puqi
# Processing Record 3 of Set 19 | malaut
# Processing Record 4 of Set 19 | zyryanovsk
# Processing Record 5 of Set 19 | lincoln
# Processing Record 6 of Set 19 | east london
# Processing Record 7 of Set 19 | georgetown
# Processing Record 8 of Set 19 | avarua
# Processing Record 9 of Set 19 | cidreira
# Processing Record 10 of Set 19 | timra
# Processing Record 11 of Set 19 | northampton
# Processing Record 12 of Set 19 | kahului
# Processing Record 13 of Set 19 | tautira
# Processing Record 14 of Set 19 | kutum
# Processing Record 15 of Set 19 | marienburg
# Processing Record 16 of Set 19 | kupang
# Processing Record 17 of Set 19 | mar del plata
# Processing Record 18 of Set 19 | tambun
# Processing Record 19 of Set 19 | codrington
# Processing Record 20 of Set 19 | miri
# Processing Record 21 of Set 19 | kandi
# Processing Record 22 of Set 19 | arraial do cabo
# Processing Record 23 of Set 19 | ilam
# Processing Record 24 of Set 19 | gushikawa
# Processing Record 25 of Set 19 | antropovo
# Processing Record 26 of Set 19 | baruun-urt
# Processing Record 27 of Set 19 | iberia
# Processing Record 28 of Set 19 | hithadhoo
# Processing Record 29 of Set 19 | denpasar
# Processing Record 30 of Set 19 | den helder
# Processing Record 31 of Set 19 | waingapu
# Processing Record 32 of Set 19 | mujiayingzi
# Processing Record 33 of Set 19 | kavieng
# Processing Record 34 of Set 19 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 19 | balikpapan
# Processing Record 36 of Set 19 | zaozerne
# Processing Record 37 of Set 19 | lichuan
# Processing Record 38 of Set 19 | fortuna
# Processing Record 39 of Set 19 | aquiraz
# Processing Record 40 of Set 19 | biak
# Processing Record 41 of Set 19 | mazamari
# Processing Record 42 of Set 19 | longyearbyen
# Processing Record 43 of Set 19 | batemans bay
# Processing Record 44 of Set 19 | taoudenni
# Processing Record 45 of Set 19 | saint-francois
# Processing Record 46 of Set 19 | rawah
# Processing Record 47 of Set 19 | matara
# Processing Record 48 of Set 19 | raymond
# Processing Record 49 of Set 19 | port augusta
# Processing Record 50 of Set 19 | qui nhon
# Processing Record 1 of Set 20 | dalby
# Processing Record 2 of Set 20 | ambon
# Processing Record 3 of Set 20 | sovetskaya gavan
# Processing Record 4 of Set 20 | vanino
# Processing Record 5 of Set 20 | kloulklubed
# Processing Record 6 of Set 20 | adrar
# Processing Record 7 of Set 20 | correntina
# Processing Record 8 of Set 20 | millbrook
# Processing Record 9 of Set 20 | vardo
# Processing Record 10 of Set 20 | mackenzie
# Processing Record 11 of Set 20 | hazorasp
# Processing Record 12 of Set 20 | veseloyarsk
# Processing Record 13 of Set 20 | sibu
# Processing Record 14 of Set 20 | ostrovnoy
# Processing Record 15 of Set 20 | vostok
# Processing Record 16 of Set 20 | faanui
# Processing Record 17 of Set 20 | weil der stadt
# Processing Record 18 of Set 20 | konza
# Processing Record 19 of Set 20 | ghatanji
# Processing Record 20 of Set 20 | santa isabel do rio negro
# Processing Record 21 of Set 20 | barcelos
# Processing Record 22 of Set 20 | sorong
# Processing Record 23 of Set 20 | san jose
# Processing Record 24 of Set 20 | mapua
# Processing Record 25 of Set 20 | sinnar
# Processing Record 26 of Set 20 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 20 | fairhope
# Processing Record 28 of Set 20 | kaitangata
# Processing Record 29 of Set 20 | lata
# Processing Record 30 of Set 20 | aquin
# Processing Record 31 of Set 20 | mahebourg
# Processing Record 32 of Set 20 | panaba
# Processing Record 33 of Set 20 | upernavik
# Processing Record 34 of Set 20 | riyadh
# Processing Record 35 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 20 | aporawan
# City not found. Skipping...
# Processing Record 37 of Set 20 | muncar
# Processing Record 38 of Set 20 | port-gentil
# Processing Record 39 of Set 20 | sao joao da barra
# Processing Record 40 of Set 20 | bilma
# Processing Record 41 of Set 20 | vesyegonsk
# Processing Record 42 of Set 20 | yumen
# Processing Record 43 of Set 20 | bandarbeyla
# Processing Record 44 of Set 20 | nicolas bravo
# Processing Record 45 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 20 | srednekolymsk
# Processing Record 47 of Set 20 | faya
# Processing Record 48 of Set 20 | korla
# Processing Record 49 of Set 20 | ribeira grande
# Processing Record 50 of Set 20 | san quintin
# Processing Record 1 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 21 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 21 | saskylakh
# Processing Record 4 of Set 21 | rio gallegos
# Processing Record 5 of Set 21 | tayoltita
# Processing Record 6 of Set 21 | houston
# Processing Record 7 of Set 21 | jacareacanga
# Processing Record 8 of Set 21 | haines junction
# Processing Record 9 of Set 21 | warri
# Processing Record 10 of Set 21 | antibes
# Processing Record 11 of Set 21 | shingu
# Processing Record 12 of Set 21 | ahuimanu
# Processing Record 13 of Set 21 | flin flon
# Processing Record 14 of Set 21 | kandri
# Processing Record 15 of Set 21 | valdemarpils
# Processing Record 16 of Set 21 | ahipara
# Processing Record 17 of Set 21 | chokurdakh
# Processing Record 18 of Set 21 | bosaso
# Processing Record 19 of Set 21 | santa
# Processing Record 20 of Set 21 | araguatins
# City not found. Skipping...
# Processing Record 21 of Set 21 | nioro
# Processing Record 22 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 21 | palmerston
# Processing Record 24 of Set 21 | jiblah
# Processing Record 25 of Set 21 | kashi
# Processing Record 26 of Set 21 | victoria
# Processing Record 27 of Set 21 | nouakchott
# Processing Record 28 of Set 21 | corrales
# Processing Record 29 of Set 21 | kulunda
# Processing Record 30 of Set 21 | aragarcas
# Processing Record 31 of Set 21 | sitka
# Processing Record 32 of Set 21 | komsomolskiy
# Processing Record 33 of Set 21 | adolfo lopez mateos
# Processing Record 34 of Set 21 | norman wells
# Processing Record 35 of Set 21 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 21 | roma
# Processing Record 37 of Set 21 | atambua
# Processing Record 38 of Set 21 | kirkuk
# Processing Record 39 of Set 21 | batagay-alyta
# Processing Record 40 of Set 21 | udachnyy
# Processing Record 41 of Set 21 | mantua
# Processing Record 42 of Set 21 | zhumadian
# Processing Record 43 of Set 21 | pangai
# Processing Record 44 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 21 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 21 | cape town
# Processing Record 47 of Set 21 | scottsbluff
# Processing Record 48 of Set 21 | hobart
# Processing Record 49 of Set 21 | afmadu
# City not found. Skipping...
# Processing Record 50 of Set 21 | kotaparh
# Processing Record 1 of Set 22 | beppu
# Processing Record 2 of Set 22 | coulihaut
# City not found. Skipping...
# Processing Record 3 of Set 22 | coihaique
# Processing Record 4 of Set 22 | bara
# Processing Record 5 of Set 22 | searcy
# Processing Record 6 of Set 22 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 22 | makinsk
# Processing Record 8 of Set 22 | meulaboh
# Processing Record 9 of Set 22 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 22 | xining
# Processing Record 11 of Set 22 | red bluff
# Processing Record 12 of Set 22 | suriapet
# Processing Record 13 of Set 22 | labuhan
# Processing Record 14 of Set 22 | north bend
# Processing Record 15 of Set 22 | aitape
# Processing Record 16 of Set 22 | stabat
# Processing Record 17 of Set 22 | oktyabrskiy
# Processing Record 18 of Set 22 | dehloran
# Processing Record 19 of Set 22 | awbari
# Processing Record 20 of Set 22 | geraldton
# Processing Record 21 of Set 22 | rocha
# Processing Record 22 of Set 22 | tecoanapa
# Processing Record 23 of Set 22 | lodja
# Processing Record 24 of Set 22 | key largo
# Processing Record 25 of Set 22 | mount pleasant
# Processing Record 26 of Set 22 | nishihara
# Processing Record 27 of Set 22 | yulara
# Processing Record 28 of Set 22 | tauberbischofsheim
# Processing Record 29 of Set 22 | siverskiy
# Processing Record 30 of Set 22 | nuuk
# Processing Record 31 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 22 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 22 | micheweni
# Processing Record 34 of Set 22 | jardim de piranhas
# Processing Record 35 of Set 22 | gambo
# Processing Record 36 of Set 22 | shahrud
# Processing Record 37 of Set 22 | luderitz
# Processing Record 38 of Set 22 | torit
# Processing Record 39 of Set 22 | cherskiy
# Processing Record 40 of Set 22 | payo
# Processing Record 41 of Set 22 | vao
# Processing Record 42 of Set 22 | kantunilkin
# Processing Record 43 of Set 22 | maceio
# Processing Record 44 of Set 22 | asau
# Processing Record 45 of Set 22 | brae
# Processing Record 46 of Set 22 | saint-jerome
# Processing Record 47 of Set 22 | kananga
# Processing Record 48 of Set 22 | namie
# Processing Record 49 of Set 22 | westerland
# Processing Record 50 of Set 22 | beyneu
# Processing Record 1 of Set 23 | staunton
# Processing Record 2 of Set 23 | constantine
# Processing Record 3 of Set 23 | baoning
# Processing Record 4 of Set 23 | mehamn
# Processing Record 5 of Set 23 | abu kamal
# Processing Record 6 of Set 23 | maymyo
# Processing Record 7 of Set 23 | excelsior springs
# Processing Record 8 of Set 23 | paucartambo
# City not found. Skipping...
# Processing Record 9 of Set 23 | mount isa
# Processing Record 10 of Set 23 | saint-augustin
# Processing Record 11 of Set 23 | sao filipe
# Processing Record 12 of Set 23 | yaring
# Processing Record 13 of Set 23 | marawi
# Processing Record 14 of Set 23 | barranca
# Processing Record 15 of Set 23 | uray
# Processing Record 16 of Set 23 | shu
# Processing Record 17 of Set 23 | cayenne
# Processing Record 18 of Set 23 | kieta
# Processing Record 19 of Set 23 | bangkalan
# Processing Record 20 of Set 23 | kantang
# Processing Record 21 of Set 23 | tallahassee
# Processing Record 22 of Set 23 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 23 | bilibino
# Processing Record 24 of Set 23 | tessalit
# Processing Record 25 of Set 23 | ardatov
# Processing Record 26 of Set 23 | mahibadhoo
# Processing Record 27 of Set 23 | lima
# Processing Record 28 of Set 23 | moree
# Processing Record 29 of Set 23 | berdigestyakh
# Processing Record 30 of Set 23 | lasa
# Processing Record 31 of Set 23 | camacha
# Processing Record 32 of Set 23 | vestmannaeyjar
# Processing Record 33 of Set 23 | cockburn town
# Processing Record 34 of Set 23 | acapulco
# Processing Record 35 of Set 23 | liku
# Processing Record 36 of Set 23 | mabaruma
# Processing Record 37 of Set 23 | muros
# Processing Record 38 of Set 23 | tukums
# Processing Record 39 of Set 23 | rovaniemi
# Processing Record 40 of Set 23 | manado
# Processing Record 41 of Set 23 | iquique
# Processing Record 42 of Set 23 | leningradskiy
# Processing Record 43 of Set 23 | laramie
# Processing Record 44 of Set 23 | poum
# Processing Record 45 of Set 23 | syasstroy
# Processing Record 46 of Set 23 | samarai
# Processing Record 47 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 23 | kavaratti
# Processing Record 49 of Set 23 | margate
# Processing Record 50 of Set 23 | quesnel
# Processing Record 1 of Set 24 | oktyabrskoye
# Processing Record 2 of Set 24 | port lincoln
# Processing Record 3 of Set 24 | carutapera
# Processing Record 4 of Set 24 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 24 | haarby
# City not found. Skipping...
# Processing Record 6 of Set 24 | pokhara
# Processing Record 7 of Set 24 | sharan
# Processing Record 8 of Set 24 | nome
# Processing Record 9 of Set 24 | vasteras
# Processing Record 10 of Set 24 | passo fundo
# Processing Record 11 of Set 24 | guerrero negro
# Processing Record 12 of Set 24 | kalawit
# Processing Record 13 of Set 24 | natal
# Processing Record 14 of Set 24 | russell
# Processing Record 15 of Set 24 | vila velha
# Processing Record 16 of Set 24 | evans
# Processing Record 17 of Set 24 | robertsport
# Processing Record 18 of Set 24 | katsuura
# Processing Record 19 of Set 24 | blackfoot
# Processing Record 20 of Set 24 | hit
# Processing Record 21 of Set 24 | hokitika
# Processing Record 22 of Set 24 | ancud
# Processing Record 23 of Set 24 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 24 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 24 | vir
# Processing Record 26 of Set 24 | lorengau
# Processing Record 27 of Set 24 | havre-saint-pierre
# Processing Record 28 of Set 24 | kurumkan
# Processing Record 29 of Set 24 | fort abbas
# Processing Record 30 of Set 24 | flinders
# Processing Record 31 of Set 24 | jalu
# Processing Record 32 of Set 24 | jibuti
# Processing Record 33 of Set 24 | coquimbo
# Processing Record 34 of Set 24 | henties bay
# Processing Record 35 of Set 24 | mitu
# Processing Record 36 of Set 24 | northam
# Processing Record 37 of Set 24 | zhigansk
# Processing Record 38 of Set 24 | scottsburgh
# City not found. Skipping...
# Processing Record 39 of Set 24 | oliveira dos brejinhos
# Processing Record 40 of Set 24 | evensk
# Processing Record 41 of Set 24 | arlit
# Processing Record 42 of Set 24 | dukat
# Processing Record 43 of Set 24 | muroran
# Processing Record 44 of Set 24 | bonthe
# Processing Record 45 of Set 24 | tual
# Processing Record 46 of Set 24 | papara
# Processing Record 47 of Set 24 | goure
# Processing Record 48 of Set 24 | sencur
# Processing Record 49 of Set 24 | kankavli
# City not found. Skipping...
# Processing Record 50 of Set 24 | broken hill
# Processing Record 1 of Set 25 | ryotsu
# Processing Record 2 of Set 25 | boksitogorsk
# Processing Record 3 of Set 25 | manta
# Processing Record 4 of Set 25 | yuci
# Processing Record 5 of Set 25 | tank
# Processing Record 6 of Set 25 | shaartuz
# City not found. Skipping...
# Processing Record 7 of Set 25 | ghanzi
# Processing Record 8 of Set 25 | lompoc
# Processing Record 9 of Set 25 | lumeje
# Processing Record 10 of Set 25 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 25 | hay river
# Processing Record 12 of Set 25 | katastarion
# Processing Record 13 of Set 25 | ambilobe
# Processing Record 14 of Set 25 | te anau
# Processing Record 15 of Set 25 | saint-pierre
# Processing Record 16 of Set 25 | vanderhoof
# Processing Record 17 of Set 25 | arawa
# Processing Record 18 of Set 25 | naraura
# Processing Record 19 of Set 25 | pangody
# Processing Record 20 of Set 25 | coxim
# Processing Record 21 of Set 25 | abu dhabi
# Processing Record 22 of Set 25 | kiama
# Processing Record 23 of Set 25 | kaluga
# Processing Record 24 of Set 25 | birin
# Processing Record 25 of Set 25 | dhidhdhoo
# Processing Record 26 of Set 25 | baneh
# Processing Record 27 of Set 25 | matay
# Processing Record 28 of Set 25 | zverinogolovskoye
# Processing Record 29 of Set 25 | erdenet
# Processing Record 30 of Set 25 | katsiveli
# City not found. Skipping...
# Processing Record 31 of Set 25 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 25 | dobryanka
# Processing Record 33 of Set 25 | grand gaube
# Processing Record 34 of Set 25 | itoman
# Processing Record 35 of Set 25 | desaguadero
# Processing Record 36 of Set 25 | kihei
# Processing Record 37 of Set 25 | werda
# Processing Record 38 of Set 25 | yamada
# Processing Record 39 of Set 25 | kenora
# Processing Record 40 of Set 25 | butembo
# Processing Record 41 of Set 25 | bathsheba
# Processing Record 42 of Set 25 | barcelona
# Processing Record 43 of Set 25 | genhe
# Processing Record 44 of Set 25 | pingliang
# Processing Record 45 of Set 25 | presidencia roque saenz pena
# Processing Record 46 of Set 25 | alekseyevka
# Processing Record 47 of Set 25 | udimskiy
# Processing Record 48 of Set 25 | carauari
# Processing Record 49 of Set 25 | gerash
# Processing Record 50 of Set 25 | aksu
# Processing Record 1 of Set 26 | igarka
# Processing Record 2 of Set 26 | pisticci
# Processing Record 3 of Set 26 | pringsewu
# Processing Record 4 of Set 26 | aneho
# Processing Record 5 of Set 26 | pangoa
# Processing Record 6 of Set 26 | mogadishu
# Processing Record 7 of Set 26 | caravelas
# Processing Record 8 of Set 26 | san vicente
# Processing Record 9 of Set 26 | constitucion
# Processing Record 10 of Set 26 | lieksa
# Processing Record 11 of Set 26 | bogalusa
# Processing Record 12 of Set 26 | rapina
# Processing Record 13 of Set 26 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 26 | japura
# Processing Record 15 of Set 26 | iqaluit
# Processing Record 16 of Set 26 | agadir
# Processing Record 17 of Set 26 | culipapa
# City not found. Skipping...
# Processing Record 18 of Set 26 | los llanos de aridane
# Processing Record 19 of Set 26 | riverton
# Processing Record 20 of Set 26 | acarau
# Processing Record 21 of Set 26 | tifton
# Processing Record 22 of Set 26 | baker city
# Processing Record 23 of Set 26 | praia da vitoria
# Processing Record 24 of Set 26 | hervey bay
# Processing Record 25 of Set 26 | dubai
# Processing Record 26 of Set 26 | wysokie mazowieckie
# Processing Record 27 of Set 26 | esperance
# Processing Record 28 of Set 26 | klaksvik
# Processing Record 29 of Set 26 | krzeszowice
# Processing Record 30 of Set 26 | rabaul
# Processing Record 31 of Set 26 | pangnirtung
# Processing Record 32 of Set 26 | sinnamary
# Processing Record 33 of Set 26 | salalah
# Processing Record 34 of Set 26 | nadym
# Processing Record 35 of Set 26 | juba
# Processing Record 36 of Set 26 | siavonga
# Processing Record 37 of Set 26 | ixtapa
# Processing Record 38 of Set 26 | riverside
# Processing Record 39 of Set 26 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 26 | enterprise
# Processing Record 41 of Set 26 | tuatapere
# Processing Record 42 of Set 26 | healdsburg
# Processing Record 43 of Set 26 | dianopolis
# City not found. Skipping...
# Processing Record 44 of Set 26 | tazovskiy
# Processing Record 45 of Set 26 | eyl
# Processing Record 46 of Set 26 | ipixuna
# Processing Record 47 of Set 26 | evanston
# Processing Record 48 of Set 26 | hermiston
# Processing Record 49 of Set 26 | gamba
# Processing Record 50 of Set 26 | tamiahua
# Processing Record 1 of Set 27 | trincomalee
# Processing Record 2 of Set 27 | suez
# Processing Record 3 of Set 27 | hami
# Processing Record 4 of Set 27 | bodrum
# Processing Record 5 of Set 27 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 27 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 27 | fare
# Processing Record 8 of Set 27 | tsabong
# Processing Record 9 of Set 27 | san andres
# Processing Record 10 of Set 27 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 27 | zelenoborskiy
# Processing Record 12 of Set 27 | katangli
# Processing Record 13 of Set 27 | san andres xecul
# Processing Record 14 of Set 27 | piacabucu
# Processing Record 15 of Set 27 | porto novo
# Processing Record 16 of Set 27 | alofi
# Processing Record 17 of Set 27 | karratha
# Processing Record 18 of Set 27 | lubango
# Processing Record 19 of Set 27 | bridlington
# Processing Record 20 of Set 27 | along
# Processing Record 21 of Set 27 | limbe
# Processing Record 22 of Set 27 | mahadday weyne
# City not found. Skipping...
# Processing Record 23 of Set 27 | dandong
# Processing Record 24 of Set 27 | harlingen
# Processing Record 25 of Set 27 | dali
# Processing Record 26 of Set 27 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 27 | tondano
# Processing Record 28 of Set 27 | alexandria
# Processing Record 29 of Set 27 | maromitsa
# Processing Record 30 of Set 27 | solnechnyy
# Processing Record 31 of Set 27 | kalmunai
# Processing Record 32 of Set 27 | montrose
# Processing Record 33 of Set 27 | antananarivo
# Processing Record 34 of Set 27 | carmo do rio claro
# Processing Record 35 of Set 27 | olinda
# Processing Record 36 of Set 27 | buariki
# City not found. Skipping...
# Processing Record 37 of Set 27 | harper
# Processing Record 38 of Set 27 | sinop
# Processing Record 39 of Set 27 | bodden town
# Processing Record 40 of Set 27 | kolo
# Processing Record 41 of Set 27 | magadan
# Processing Record 42 of Set 27 | agadez
# Processing Record 43 of Set 27 | nichinan
# Processing Record 44 of Set 27 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 27 | sao borja
# Processing Record 46 of Set 27 | aktash
# Processing Record 47 of Set 27 | akureyri
# Processing Record 48 of Set 27 | lamu
# Processing Record 49 of Set 27 | howard springs
# Processing Record 50 of Set 27 | troitskoye
# Processing Record 1 of Set 28 | kamphaeng phet
# Processing Record 2 of Set 28 | luangwa
# Processing Record 3 of Set 28 | san rafael
# Processing Record 4 of Set 28 | bobo dioulasso
# Processing Record 5 of Set 28 | dharmavaram
# Processing Record 6 of Set 28 | imbituba
# Processing Record 7 of Set 28 | pingshan
# Processing Record 8 of Set 28 | biltine
# Processing Record 9 of Set 28 | makokou
# Processing Record 10 of Set 28 | maragogi
# Processing Record 11 of Set 28 | crispiano
# Processing Record 12 of Set 28 | grand forks
# Processing Record 13 of Set 28 | victor harbor
# Processing Record 14 of Set 28 | port macquarie
# Processing Record 15 of Set 28 | araouane
# Processing Record 16 of Set 28 | husavik
# Processing Record 17 of Set 28 | mumford
# Processing Record 18 of Set 28 | urubicha
# Processing Record 19 of Set 28 | elko
# Processing Record 20 of Set 28 | axim
# Processing Record 21 of Set 28 | abha
# Processing Record 22 of Set 28 | lagos
# Processing Record 23 of Set 28 | bulgan
# Processing Record 24 of Set 28 | cuamba
# Processing Record 25 of Set 28 | rudovci
# Processing Record 26 of Set 28 | yarmouth
# Processing Record 27 of Set 28 | guiberoua
# Processing Record 28 of Set 28 | nata
# Processing Record 29 of Set 28 | tevaitoa
# Processing Record 30 of Set 28 | back mountain
# Processing Record 31 of Set 28 | qaqortoq
# Processing Record 32 of Set 28 | floro
# Processing Record 33 of Set 28 | roswell
# Processing Record 34 of Set 28 | taltal
# Processing Record 35 of Set 28 | mapiripan
# Processing Record 36 of Set 28 | phrai bung
# City not found. Skipping...
# Processing Record 37 of Set 28 | bambanglipuro
# Processing Record 38 of Set 28 | at-bashi
# Processing Record 39 of Set 28 | powell river
# Processing Record 40 of Set 28 | havelock
# Processing Record 41 of Set 28 | akyab
# Processing Record 42 of Set 28 | creston
# Processing Record 43 of Set 28 | moindou
# Processing Record 44 of Set 28 | khani
# Processing Record 45 of Set 28 | galveston
# Processing Record 46 of Set 28 | kasongo-lunda
# Processing Record 47 of Set 28 | palmer
# Processing Record 48 of Set 28 | talcahuano
# Processing Record 49 of Set 28 | berlevag
# Processing Record 50 of Set 28 | eureka
# Processing Record 1 of Set 29 | montepuez
# Processing Record 2 of Set 29 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 29 | trinidad
# Processing Record 4 of Set 29 | townsville
# Processing Record 5 of Set 29 | san isidro
# Processing Record 6 of Set 29 | ginda
# Processing Record 7 of Set 29 | san ciro de acosta
# Processing Record 8 of Set 29 | khakhea
# Processing Record 9 of Set 29 | kyzyl-suu
# Processing Record 10 of Set 29 | rancho veloz
# Processing Record 11 of Set 29 | neiafu
# Processing Record 12 of Set 29 | buala
# Processing Record 13 of Set 29 | mus
# Processing Record 14 of Set 29 | walvis bay
# Processing Record 15 of Set 29 | gabane
# Processing Record 16 of Set 29 | wanning
# Processing Record 17 of Set 29 | huarmey
# Processing Record 18 of Set 29 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 29 | san policarpo
# Processing Record 20 of Set 29 | imeni zhelyabova
# Processing Record 21 of Set 29 | port arthur
# Processing Record 22 of Set 29 | beni suef
# Processing Record 23 of Set 29 | gat
# Processing Record 24 of Set 29 | poya
# Processing Record 25 of Set 29 | mao
# Processing Record 26 of Set 29 | north platte
# Processing Record 27 of Set 29 | manadhoo
# Processing Record 28 of Set 29 | semey
# Processing Record 29 of Set 29 | kapit
# Processing Record 30 of Set 29 | sainte-marie
# Processing Record 31 of Set 29 | tanete
# Processing Record 32 of Set 29 | omboue
# Processing Record 33 of Set 29 | xadani
# City not found. Skipping...
# Processing Record 34 of Set 29 | ankazoabo
# Processing Record 35 of Set 29 | morro bay
# Processing Record 36 of Set 29 | lazaro cardenas
# Processing Record 37 of Set 29 | kushmurun
# Processing Record 38 of Set 29 | amarante do maranhao
# Processing Record 39 of Set 29 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 29 | phayao
# Processing Record 41 of Set 29 | bollnas
# Processing Record 42 of Set 29 | beidao
# Processing Record 43 of Set 29 | shimoda
# Processing Record 44 of Set 29 | glasgow
# Processing Record 45 of Set 29 | khawhai
# Processing Record 46 of Set 29 | mogwase
# Processing Record 47 of Set 29 | kysyl-syr
# Processing Record 48 of Set 29 | virden
# Processing Record 49 of Set 29 | tir pol
# City not found. Skipping...
# Processing Record 50 of Set 29 | popesti
# Processing Record 1 of Set 30 | serenje
# Processing Record 2 of Set 30 | bayangol
# Processing Record 3 of Set 30 | duku
# Processing Record 4 of Set 30 | holoby
# Processing Record 5 of Set 30 | miandrivazo
# Processing Record 6 of Set 30 | atbasar
# Processing Record 7 of Set 30 | varberg
# Processing Record 8 of Set 30 | hawick
# Processing Record 9 of Set 30 | bealanana
# Processing Record 10 of Set 30 | tarare
# Processing Record 11 of Set 30 | san lorenzo
# Processing Record 12 of Set 30 | raudeberg
# Processing Record 13 of Set 30 | banda aceh
# Processing Record 14 of Set 30 | baykit
# Processing Record 15 of Set 30 | soyo
# Processing Record 16 of Set 30 | tours
# Processing Record 17 of Set 30 | yeniseysk
# Processing Record 18 of Set 30 | sakakah
# Processing Record 19 of Set 30 | asheville
# Processing Record 20 of Set 30 | rio branco
# Processing Record 21 of Set 30 | beloha
# Processing Record 22 of Set 30 | lavrentiya
# Processing Record 23 of Set 30 | silchar
# Processing Record 24 of Set 30 | sommerda
# Processing Record 25 of Set 30 | gobabis
# Processing Record 26 of Set 30 | ust-ordynskiy
# Processing Record 27 of Set 30 | bremerton
# Processing Record 28 of Set 30 | mirpur mathelo
# Processing Record 29 of Set 30 | conakry
# Processing Record 30 of Set 30 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 30 | pitimbu
# Processing Record 32 of Set 30 | kargopol
# Processing Record 33 of Set 30 | zeya
# Processing Record 34 of Set 30 | yerbogachen
# Processing Record 35 of Set 30 | busing
# Processing Record 36 of Set 30 | zhanakorgan
# Processing Record 37 of Set 30 | shawinigan
# Processing Record 38 of Set 30 | shar
# Processing Record 39 of Set 30 | pucallpa
# Processing Record 40 of Set 30 | tete
# Processing Record 41 of Set 30 | tocopilla
# Processing Record 42 of Set 30 | chunoyar
# Processing Record 43 of Set 30 | hofn
# Processing Record 44 of Set 30 | jaisinghnagar
# Processing Record 45 of Set 30 | diffa
# Processing Record 46 of Set 30 | watrous
# Processing Record 47 of Set 30 | phan thiet
# Processing Record 48 of Set 30 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 30 | eldikan
# City not found. Skipping...
# Processing Record 50 of Set 30 | mayor pablo lagerenza
# Processing Record 1 of Set 31 | narsaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Alfred -33.5906   26.8910     59.86        81          11        5.75
# 1      Ushuaia -54.8000  -68.3000     38.86        81           0        0.00
# 2     Weligama   5.9667   80.4167     83.59        79          99       11.99
# 3       Torbay  47.6666  -52.7314     40.28        92          56        3.76
# 4   Naryan-Mar  67.6713   53.0870     19.04        95         100        9.62
# 5      Rikitea -23.1203 -134.9692     76.46        71         100        5.32
# 6        Vaini -21.2000 -175.2000     80.76        89          75        9.22
# 7     Bardiyah  31.7561   25.0865     70.41        51         100       17.02
# 8  Provideniya  64.3833 -173.3000     28.33        51          15       12.53
# 9         Emba  48.8264   58.1442     50.67        68          16       13.29
#
#   Country      Current Description
# 0      ZA               few clouds
# 1      AR                clear sky
# 2      LK          overcast clouds
# 3      CA            broken clouds
# 4      RU          overcast clouds
# 5      PF          overcast clouds
# 6      TO  light intensity drizzle
# 7      LY          overcast clouds
# 8      RU               few clouds
# 9      KZ               few clouds

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
city_data_df = city_data_df[['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']]

# %%
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Alfred      ZA -33.5906   26.8910     59.86        81          11
# 1      Ushuaia      AR -54.8000  -68.3000     38.86        81           0
# 2     Weligama      LK   5.9667   80.4167     83.59        79          99
# 3       Torbay      CA  47.6666  -52.7314     40.28        92          56
# 4   Naryan-Mar      RU  67.6713   53.0870     19.04        95         100
# 5      Rikitea      PF -23.1203 -134.9692     76.46        71         100
# 6        Vaini      TO -21.2000 -175.2000     80.76        89          75
# 7     Bardiyah      LY  31.7561   25.0865     70.41        51         100
# 8  Provideniya      RU  64.3833 -173.3000     28.33        51          15
# 9         Emba      KZ  48.8264   58.1442     50.67        68          16
#
#    Wind Speed      Current Description
# 0        5.75               few clouds
# 1        0.00                clear sky
# 2       11.99          overcast clouds
# 3        3.76            broken clouds
# 4        9.62          overcast clouds
# 5        5.32          overcast clouds
# 6        9.22  light intensity drizzle
# 7       17.02          overcast clouds
# 8       12.53               few clouds
# 9       13.29               few clouds

# %%
output_data_file = "WeatherPy_database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
